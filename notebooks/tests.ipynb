# %%
import renal_sight
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import renal_sight
#
# File ~/code/AntonioICP/renal_sight/renal_sight/__init__.py:1
# ----> 1 from renal_sight.ml_logic import (
#       2     load_datasets,
#       3     get_datasets,
#       4     preprocess_image_for_backbone,
#       5     build_baseline_model,
#       6     build_pretrained_model,
#       7     load_model,
#       8     save_model,
#       9     predict_with_confidence,
#      10     generate_report
#      11 )
#
# ImportError: cannot import name 'load_datasets' from 'renal_sight.ml_logic' (/Users/acisneros/code/AntonioICP/renal_sight/renal_sight/ml_logic/__init__.py)

# %%
from renal_sight.ml_logic.preprocessing import load_datasets, get_datasets, efficientnet_preprocess

# %%
ORIGINAL_DIR = "../raw_data/Original"
AUGMENTED_DIR = "../raw_data/Augmented"

# %%
# Load from disk
train_dataset, val_dataset, test_dataset = load_datasets(AUGMENTED_DIR, ORIGINAL_DIR)
# Out:
# Found 35457 files belonging to 2 classes.
# Found 3364 files belonging to 2 classes.
# 2026-03-14 11:48:28.851612: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2026-03-14 11:48:28.851672: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2026-03-14 11:48:28.851675: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.88 GB
# 2026-03-14 11:48:28.851695: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-14 11:48:28.851707: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Apply backbone preprocessing
train_eff, val_eff, test_eff = get_datasets(train_dataset, val_dataset, test_dataset, efficientnet_preprocess)

# %%
from renal_sight.ml_logic.model import (
    build_baseline_model,
    build_pretrained_model,
    save_model,
    load_model
)
print("✅ model.py imported correctly!")
# Out:
# ✅ model.py imported correctly!

# %%
from renal_sight.ml_logic.predict import (
    predict_with_confidence,
)
print("✅ predict.py imported correctly!")
# Out:
# ✅ predict.py imported correctly!

# %%
from renal_sight.ml_logic.report import generate_report
print("✅ report.py imported correctly!")
# Out:
# ✅ report.py imported correctly!

# %%
from renal_sight.ml_logic.preprocessing import (
    load_datasets,
    get_datasets,
    preprocess_image_for_backbone
)

# %%
from renal_sight.ml_logic.model import (
    build_baseline_model,
    build_pretrained_model,
    load_model,
    save_model
)

# %%
from renal_sight.ml_logic.predict import predict_with_confidence

# %%
from renal_sight.ml_logic.report import generate_report
